# %%
# !pip install html2text

# %%
import requests
from bs4 import BeautifulSoup
import html2text
import re
import time
from urllib.parse import urljoin, urlparse
import json
from typing import Dict, List, Tuple, Optional, Set
from collections import deque

# %% [markdown]
# ## **Grabbing Reliable Parkinson's Content From the Web**

# %% [markdown]
# | Organization Name                                               | Country/Region            | Description                                      |
# |------------------------------------------------------------------|---------------------------|--------------------------------------------------|
# | Parkinson’s Foundation                                           | USA (Global reach)        | [parkinson.org](https://www.parkinson.org/)     |
# | Michael J. Fox Foundation for Parkinson’s Research              | USA (Global reach)        | [michaeljfox.org](https://www.michaeljfox.org/) |
# | American Parkinson Disease Association (APDA)                   | USA                       | [apdaparkinson.org](https://www.apdaparkinson.org/) |
# | Parkinson Canada                                                | Canada                    | [parkinson.ca](https://www.parkinson.ca/)       |
# | European Parkinson’s Disease Association (EPDA)                 | Europe (Pan-European)     | [parkinsonseurope.org](https://parkinsonseurope.org/) |
# | Parkinson’s UK                                                  | United Kingdom            | [parkinsons.org.uk](https://www.parkinsons.org.uk/) |
# | Davis Phinney Foundation                                        | USA                       | [davisphinneyfoundation.org](https://davisphinneyfoundation.org/) |
# | PMD Alliance                                                    | USA                       | [pmdalliance.org](https://www.pmdalliance.org/) |
# | ParkinsonNet                                                    | Netherlands               | [parkinsonnet.com](https://www.parkinsonnet.com/) |

# %% [markdown]
# Grab all main pages and secondary pages with a limit of 50 pages and 3 levels deep, only crawls pages within the same domain + URLs for videos and podcast ressources

# %%
import requests
from bs4 import BeautifulSoup
import html2text
import re
import time
from urllib.parse import urljoin, urlparse
import json
from typing import Dict, List, Tuple, Optional, Set
from collections import deque

class ParkinsonsContentScraper:
    def __init__(self, max_pages_per_org: int = 50, max_depth: int = 3):
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        })

        # Crawling limits
        self.max_pages_per_org = max_pages_per_org
        self.max_depth = max_depth

        # Parkinson's organization URLs
        self.organizations = {
            "Parkinson's Foundation": "https://www.parkinson.org/",
            "Michael J. Fox Foundation": "https://www.michaeljfox.org/",
            "American Parkinson Disease Association": "https://www.apdaparkinson.org/",
            "Parkinson Canada": "https://www.parkinson.ca/",
            "European Parkinson's Disease Association": "https://parkinsonseurope.org/",
            "Parkinson's UK": "https://www.parkinsons.org.uk/",
            "Davis Phinney Foundation": "https://davisphinneyfoundation.org/",
            "PMD Alliance": "https://www.pmdalliance.org/",
            "ParkinsonNet": "https://www.parkinsonnet.com/"
        }

        # Video/podcast indicators
        self.media_indicators = {
            'video': [
                'youtube.com', 'vimeo.com', 'video', 'watch', 'webinar',
                'presentation', 'lecture', 'talk', 'interview'
            ],
            'podcast': [
                'podcast', 'audio', 'listen', 'episode', 'spotify.com',
                'apple.com/podcasts', 'soundcloud.com', 'anchor.fm'
            ]
        }

        # URLs to exclude from crawling
        self.excluded_patterns = [
            r'.*\.(pdf|doc|docx|xls|xlsx|ppt|pptx|zip|rar|tar|gz)$',
            r'.*/(login|register|signin|signup|cart|checkout|donate|payment)',
            r'.*\?.*utm_',  # UTM tracking parameters
            r'.*#.*',  # Anchor links
            r'.*/search.*',
            r'.*/tag/.*',
            r'.*/category/.*',
            r'.*/author/.*',
            r'.*/wp-admin/.*',
            r'.*/wp-content/.*',
            r'.*\.php\?.*',
            r'mailto:.*',
            r'tel:.*',
            r'javascript:.*'
        ]

    def get_page_content(self, url: str) -> Optional[Tuple[str, Dict]]:
        """
        Retrieve text content and metadata from a given URL.

        Args:
            url (str): The URL to fetch content from.

        Returns:
            tuple: A tuple containing the text content (str) and metadata (dict).
        """
        try:
            response = self.session.get(url, timeout=10)
            if response.status_code == 500:
                print(f"Server error for {url}")
                return None
            if response.status_code != 200:
                print(f"HTTP {response.status_code} for {url}")
                return None

            # Parse the HTML content
            soup = BeautifulSoup(response.content, 'html.parser')

            # Remove js and css code
            for script in soup(["script", "style"]):
                script.extract()

            # Extract text in markdown format
            html = str(soup)
            html2text_instance = html2text.HTML2Text()
            html2text_instance.images_to_alt = True
            html2text_instance.body_width = 0
            html2text_instance.single_line_break = True
            text = html2text_instance.handle(html)

            # Extract page metadata
            try:
                page_title = soup.title.string.strip() if soup.title else ""
            except:
                page_title = urlparse(url).path[1:].replace("/", "-")

            meta_description = soup.find("meta", attrs={"name": "description"})
            meta_keywords = soup.find("meta", attrs={"name": "keywords"})

            description = meta_description.get("content") if meta_description else page_title
            keywords = meta_keywords.get("content") if meta_keywords else ""

            metadata = {
                'title': page_title,
                'url': url,
                'description': description,
                'keywords': keywords
            }

            return text, metadata

        except Exception as e:
            print(f"Error processing {url}: {str(e)}")
            return None

    def extract_media_links(self, soup: BeautifulSoup, base_url: str) -> List[Dict]:
        """
        Extract video and podcast links with descriptions from a webpage.

        Args:
            soup: BeautifulSoup object of the webpage
            base_url: Base URL for resolving relative links

        Returns:
            List of dictionaries containing media information
        """
        media_links = []

        # Find all links
        links = soup.find_all('a', href=True)

        for link in links:
            href = link.get('href')
            if not href:
                continue

            # Convert relative URLs to absolute
            full_url = urljoin(base_url, href)

            # Get link text and surrounding context
            link_text = link.get_text(strip=True)

            # Check if it's a media link
            media_type = self.classify_media_link(full_url, link_text)

            if media_type:
                # Extract description from various sources
                description = self.extract_media_description(link, link_text)

                media_info = {
                    'type': media_type,
                    'url': full_url,
                    'title': link_text,
                    'description': description,
                    'source_page': base_url
                }

                media_links.append(media_info)

        # Also look for embedded videos
        embedded_media = self.extract_embedded_media(soup, base_url)
        media_links.extend(embedded_media)

        return media_links

    def classify_media_link(self, url: str, text: str) -> Optional[str]:
        """
        Classify whether a link is a video or podcast based on URL and text.

        Args:
            url: The URL to classify
            text: The link text

        Returns:
            'video', 'podcast', or None
        """
        url_lower = url.lower()
        text_lower = text.lower()

        # Check for video indicators
        for indicator in self.media_indicators['video']:
            if indicator in url_lower or indicator in text_lower:
                return 'video'

        # Check for podcast indicators
        for indicator in self.media_indicators['podcast']:
            if indicator in url_lower or indicator in text_lower:
                return 'podcast'

        return None

    def extract_media_description(self, link_element, link_text: str) -> str:
        """
        Extract description for media content from surrounding HTML context.

        Args:
            link_element: BeautifulSoup link element
            link_text: Text content of the link

        Returns:
            Description string
        """
        description_parts = [link_text]

        # Check parent elements for additional context
        parent = link_element.parent
        if parent:
            # Look for title attributes
            title_attr = link_element.get('title')
            if title_attr:
                description_parts.append(title_attr)

            # Look for surrounding text in parent elements
            for level in range(3):  # Check up to 3 levels up
                if parent:
                    parent_text = parent.get_text(strip=True)
                    if parent_text and parent_text != link_text and len(parent_text) < 500:
                        description_parts.append(parent_text)
                    parent = parent.parent
                else:
                    break

        # Look for adjacent elements with descriptions
        next_sibling = link_element.find_next_sibling()
        if next_sibling:
            sibling_text = next_sibling.get_text(strip=True)
            if sibling_text and len(sibling_text) < 200:
                description_parts.append(sibling_text)

        return " | ".join(filter(None, description_parts))

    def extract_embedded_media(self, soup: BeautifulSoup, base_url: str) -> List[Dict]:
        """
        Extract embedded videos and audio content.

        Args:
            soup: BeautifulSoup object
            base_url: Base URL

        Returns:
            List of embedded media information
        """
        embedded_media = []

        # YouTube embeds
        youtube_embeds = soup.find_all('iframe', src=re.compile(r'youtube\.com|youtu\.be'))
        for embed in youtube_embeds:
            src = embed.get('src')
            title = embed.get('title') or "YouTube Video"

            media_info = {
                'type': 'video',
                'url': src,
                'title': title,
                'description': f"Embedded YouTube video: {title}",
                'source_page': base_url
            }
            embedded_media.append(media_info)

        # Vimeo embeds
        vimeo_embeds = soup.find_all('iframe', src=re.compile(r'vimeo\.com'))
        for embed in vimeo_embeds:
            src = embed.get('src')
            title = embed.get('title') or "Vimeo Video"

            media_info = {
                'type': 'video',
                'url': src,
                'title': title,
                'description': f"Embedded Vimeo video: {title}",
                'source_page': base_url
            }
            embedded_media.append(media_info)

        # Audio elements
        audio_elements = soup.find_all('audio')
        for audio in audio_elements:
            src = audio.get('src')
            if src:
                title = audio.get('title') or "Audio Content"
                media_info = {
                    'type': 'podcast',
                    'url': urljoin(base_url, src),
                    'title': title,
                    'description': f"Audio content: {title}",
                    'source_page': base_url
                }
                embedded_media.append(media_info)

        return embedded_media

    def is_valid_url(self, url: str, base_domain: str) -> bool:
        """
        Check if a URL should be crawled based on domain and exclusion patterns.

        Args:
            url: URL to check
            base_domain: Base domain of the organization

        Returns:
            True if URL should be crawled
        """
        try:
            parsed_url = urlparse(url)

            # Must be same domain or subdomain
            if base_domain not in parsed_url.netloc:
                return False

            # Check exclusion patterns
            for pattern in self.excluded_patterns:
                if re.match(pattern, url, re.IGNORECASE):
                    return False

            return True
        except:
            return False

    def extract_internal_links(self, soup: BeautifulSoup, base_url: str, base_domain: str) -> Set[str]:
        """
        Extract internal links from a webpage.

        Args:
            soup: BeautifulSoup object
            base_url: Base URL for resolving relative links
            base_domain: Base domain to filter links

        Returns:
            Set of valid internal URLs
        """
        internal_links = set()

        # Find all links
        links = soup.find_all('a', href=True)

        for link in links:
            href = link.get('href')
            if not href:
                continue

            # Convert relative URLs to absolute
            full_url = urljoin(base_url, href)

            # Clean URL (remove fragments and query params we don't want)
            parsed = urlparse(full_url)
            clean_url = f"{parsed.scheme}://{parsed.netloc}{parsed.path}"

            # Remove trailing slash for consistency
            if clean_url.endswith('/') and len(clean_url) > 1:
                clean_url = clean_url[:-1]

            # Check if URL is valid for crawling
            if self.is_valid_url(clean_url, base_domain):
                internal_links.add(clean_url)

        return internal_links

    def crawl_organization_pages(self, org_name: str, base_url: str) -> Dict:
        """
        Crawl all pages from an organization's website using breadth-first search.

        Args:
            org_name: Name of the organization
            base_url: Base URL of the organization

        Returns:
            Dictionary containing all scraped pages and media
        """
        print(f"Crawling {org_name}...")

        # Parse base domain
        base_domain = urlparse(base_url).netloc

        # Initialize crawling data structures
        visited_urls = set()
        to_visit = deque([(base_url, 0)])  # (url, depth)
        scraped_pages = {}
        all_media = []

        while to_visit and len(visited_urls) < self.max_pages_per_org:
            current_url, depth = to_visit.popleft()

            # Skip if already visited or max depth reached
            if current_url in visited_urls or depth > self.max_depth:
                continue

            print(f"  Crawling (depth {depth}): {current_url}")
            visited_urls.add(current_url)

            # Get page content
            page_data = self.get_page_content(current_url)
            if not page_data:
                continue

            text, metadata = page_data

            # Store page content
            scraped_pages[current_url] = {
                'text': text,
                'metadata': metadata,
                'depth': depth,
                'crawled_at': time.strftime('%Y-%m-%d %H:%M:%S')
            }

            # Extract media from this page
            try:
                response = self.session.get(current_url, timeout=10)
                if response.status_code == 200:
                    soup = BeautifulSoup(response.content, 'html.parser')

                    # Extract media links
                    page_media = self.extract_media_links(soup, current_url)
                    all_media.extend(page_media)

                    # Extract internal links for further crawling
                    if depth < self.max_depth:
                        internal_links = self.extract_internal_links(soup, current_url, base_domain)
                        for link in internal_links:
                            if link not in visited_urls:
                                to_visit.append((link, depth + 1))

            except Exception as e:
                print(f"    Error processing {current_url}: {str(e)}")
                continue

            # Be respectful with requests
            time.sleep(1)

        # Remove duplicate media
        unique_media = []
        seen_urls = set()
        for media in all_media:
            if media['url'] not in seen_urls:
                unique_media.append(media)
                seen_urls.add(media['url'])

        return {
            'organization': org_name,
            'base_url': base_url,
            'total_pages_crawled': len(scraped_pages),
            'pages_content': scraped_pages,
            'media_content': {
                'videos': [m for m in unique_media if m['type'] == 'video'],
                'podcasts': [m for m in unique_media if m['type'] == 'podcast'],
                'total_media_found': len(unique_media)
            },
            'crawl_summary': {
                'pages_visited': list(visited_urls),
                'total_pages': len(visited_urls),
                'max_depth_reached': max([data['depth'] for data in scraped_pages.values()]) if scraped_pages else 0
            }
        }

    def scrape_organization(self, org_name: str, base_url: str) -> Dict:
        """
        Scrape content from a single organization (legacy method - use crawl_organization_pages for full crawling).

        Args:
            org_name: Name of the organization
            base_url: Base URL of the organization

        Returns:
            Dictionary containing scraped content and media
        """
        return self.crawl_organization_pages(org_name, base_url)

    def scrape_all_organizations(self) -> Dict:
        """
        Scrape content from all Parkinson's organizations with full page crawling.

        Returns:
            Dictionary containing all scraped content
        """
        results = {}

        for org_name, url in self.organizations.items():
            try:
                results[org_name] = self.crawl_organization_pages(org_name, url)
                # Be respectful with requests between organizations
                time.sleep(3)
            except Exception as e:
                print(f"Error scraping {org_name}: {str(e)}")
                results[org_name] = {'organization': org_name, 'error': str(e)}

        return results

    def get_content_summary(self, results: Dict) -> Dict:
        """
        Generate a summary of all scraped content.

        Args:
            results: Results from scrape_all_organizations()

        Returns:
            Summary statistics
        """
        summary = {
            'total_organizations': len(results),
            'successful_crawls': 0,
            'failed_crawls': 0,
            'total_pages_scraped': 0,
            'total_videos_found': 0,
            'total_podcasts_found': 0,
            'organizations_summary': {}
        }

        for org_name, data in results.items():
            if 'error' in data:
                summary['failed_crawls'] += 1
                summary['organizations_summary'][org_name] = {'status': 'failed', 'error': data['error']}
            else:
                summary['successful_crawls'] += 1
                summary['total_pages_scraped'] += data['total_pages_crawled']
                summary['total_videos_found'] += len(data['media_content']['videos'])
                summary['total_podcasts_found'] += len(data['media_content']['podcasts'])

                summary['organizations_summary'][org_name] = {
                    'status': 'success',
                    'pages_crawled': data['total_pages_crawled'],
                    'videos_found': len(data['media_content']['videos']),
                    'podcasts_found': len(data['media_content']['podcasts']),
                    'max_depth_reached': data['crawl_summary']['max_depth_reached']
                }

        return summary

    def save_results(self, results: Dict, filename: str = 'parkinsons_content.json'):
        """
        Save scraped results to a JSON file.

        Args:
            results: Scraped content dictionary
            filename: Output filename
        """
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(results, f, indent=2, ensure_ascii=False)

        print(f"Results saved to {filename}")


# Usage example
if __name__ == "__main__":
    # Initialize scraper with custom limits
    scraper = ParkinsonsContentScraper(
        max_pages_per_org=100,  # Maximum pages to crawl per organization
        max_depth=3             # Maximum depth to crawl (0 = main page only)
    )

    # Option 1: Scrape all organizations
    print("Starting full crawl of all organizations...")
    all_results = scraper.scrape_all_organizations()

    # Save results
    scraper.save_results(all_results, 'parkinsons_full_crawl.json')

    # Generate and display summary
    summary = scraper.get_content_summary(all_results)
    scraper.save_results(summary, 'parkinsons_crawl_summary.json')

    print("\n=== CRAWLING SUMMARY ===")
    print(f"Total Organizations: {summary['total_organizations']}")
    print(f"Successful Crawls: {summary['successful_crawls']}")
    print(f"Failed Crawls: {summary['failed_crawls']}")
    print(f"Total Pages Scraped: {summary['total_pages_scraped']}")
    print(f"Total Videos Found: {summary['total_videos_found']}")
    print(f"Total Podcasts Found: {summary['total_podcasts_found']}")

    print("\n=== ORGANIZATION DETAILS ===")
    for org_name, org_data in summary['organizations_summary'].items():
        if org_data['status'] == 'success':
            print(f"{org_name}: {org_data['pages_crawled']} pages, {org_data['videos_found']} videos, {org_data['podcasts_found']} podcasts (depth: {org_data['max_depth_reached']})")
        else:
            print(f"{org_name}: ERROR - {org_data['error']}")

    # Option 2: Scrape a single organization for testing
    # single_org_results = scraper.crawl_organization_pages("Parkinson's Foundation", "https://www.parkinson.org/")
    # scraper.save_results(single_org_results, 'single_org_test.json')
# Out:
# Starting full crawl of all organizations...
# Crawling Parkinson's Foundation...
#   Crawling (depth 0): https://www.parkinson.org/
#   Crawling (depth 1): https://www.parkinson.org/understanding-parkinsons/movement-symptoms
#   Crawling (depth 1): https://www.parkinson.org/advancing-research/advocate-research
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons/stories
#   Crawling (depth 1): https://www.parkinson.org/understanding-parkinsons/10-early-signs
#   Crawling (depth 1): https://www.parkinson.org/resources-support/carepartners
#   Crawling (depth 1): https://www.parkinson.org/about-us/careers
#   Crawling (depth 1): https://www.parkinson.org/advancing-research/our-research/pdgeneration
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons/finding-care
#   Crawling (depth 1): https://www.parkinson.org/how-to-help/tribute
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons/management
#   Crawling (depth 1): https://www.parkinson.org/resources-support/online-education
#   Crawling (depth 1): https://www.parkinson.org/about-us/contact
#   Crawling (depth 1): https://www.parkinson.org/advancing-research/parkinsons-virtual-biotech
#   Crawling (depth 1): https://www.parkinson.org/resources-support/events
#   Crawling (depth 1): https://www.parkinson.org/resources-support/blog
#   Crawling (depth 1): https://www.parkinson.org/about-us/news/new-chief-medical-officer
#   Crawling (depth 1): https://www.parkinson.org/understanding-parkinsons/getting-diagnosed
#   Crawling (depth 1): https://www.parkinson.org/understanding-parkinsons
#   Crawling (depth 1): https://www.parkinson.org/resources-support/professionals
#   Crawling (depth 1): https://www.parkinson.org/resources-support/pd-library/order-publications
#   Crawling (depth 1): https://www.parkinson.org/understanding-parkinsons/causes
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons/care-programs
#   Crawling (depth 1): https://www.parkinson.org/events/2025/SEAmbassadors
#   Crawling (depth 1): https://www.parkinson.org/how-to-help
#   Crawling (depth 1): https://www.parkinson.org/events/2025/July18FF
#   Crawling (depth 1): https://www.parkinson.org/how-to-help/fundraise
#   Crawling (depth 1): https://www.parkinson.org/advancing-research/for-researchers
#   Crawling (depth 1): https://www.parkinson.org/events/2025/July16WW
#   Crawling (depth 1): https://www.parkinson.org/advancing-research/finding-cure
#   Crawling (depth 1): https://www.parkinson.org/resources-support
#   Crawling (depth 1): https://www.parkinson.org/events/2025/July14MM
#   Crawling (depth 1): https://www.parkinson.org/advancing-research
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons
#   Crawling (depth 1): https://www.parkinson.org/how-to-help/volunteer
#   Crawling (depth 1): https://www.parkinson.org
#   Crawling (depth 1): https://www.parkinson.org/how-to-help/more-ways-to-give/planned-giving
# HTTP 403 for https://www.parkinson.org/how-to-help/more-ways-to-give/planned-giving
#   Crawling (depth 1): https://www.parkinson.org/espanol
#   Crawling (depth 1): https://www.parkinson.org/resources-support/hospital-safety-guide
#   Crawling (depth 1): https://www.parkinson.org/how-to-help/why-support-us
#   Crawling (depth 1): https://www.parkinson.org/blog/awareness/sleep-disorders-expert-briefing
#   Crawling (depth 1): https://www.parkinson.org/resources-support/find-your-chapter
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons/legal-financial
#   Crawling (depth 1): https://www.parkinson.org/about-us
#   Crawling (depth 1): https://www.parkinson.org/resources-support/community-grants
#   Crawling (depth 1): https://www.parkinson.org/resources-support/pd-library
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons/stories/jack-ryan
#   Crawling (depth 1): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms
#   Crawling (depth 1): https://www.parkinson.org/about-us/press-room
#   Crawling (depth 1): https://www.parkinson.org/understanding-parkinsons/statistics
#   Crawling (depth 1): https://www.parkinson.org/blog/advancing-research/early-onset-parkinsons
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons/emotional-mental-health
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons/treatment
#   Crawling (depth 1): https://www.parkinson.org/advancing-research/our-research
#   Crawling (depth 1): https://www.parkinson.org/resources-support/helpline
#   Crawling (depth 1): https://www.parkinson.org/how-to-help/more-ways-to-give
#   Crawling (depth 1): https://www.parkinson.org/blog/awareness/2025-survey
#   Crawling (depth 1): https://www.parkinson.org/privacy
#   Crawling (depth 1): https://www.parkinson.org/how-to-help/corporate-sponsors
#   Crawling (depth 1): https://www.parkinson.org/living-with-parkinsons/new-to-parkinsons
#   Crawling (depth 1): https://www.parkinson.org/advancing-research/join-study
#   Crawling (depth 1): https://www.parkinson.org/your-area
#   Crawling (depth 1): https://www.parkinson.org/understanding-parkinsons/what-is-parkinsons
#   Crawling (depth 2): https://www.parkinson.org/library/fact-sheets/occupational-therapy
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/pain
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/skin
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/movement-symptoms/small-handwriting
#   Crawling (depth 2): https://www.parkinson.org/blog/awareness/nourishing-wellness
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/what-is-parkinsons/myths
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/getting-diagnosed/conditions-that-mimic-parkinsons
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/movement-symptoms/drooling
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/vision
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/weight-management
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/apathy
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/movement-symptoms/stooped-posture
#   Crawling (depth 2): https://www.parkinson.org/advancing-research/our-research/parkinsons-outcomes-project
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/movement-symptoms/tremor
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/movement-symptoms/dystonia
#   Crawling (depth 2): https://www.parkinson.org/library/fact-sheets/10-signs
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/getting-diagnosed/biomarkers
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/causes/genetics
#   Crawling (depth 2): https://www.parkinson.org/resources-support/online-education/pdhealth
#   Crawling (depth 2): https://www.parkinson.org/library/fact-sheets/managing-off-time
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/movement-symptoms/rigidity
#   Crawling (depth 2): https://www.parkinson.org/blog/awareness/what-professionals-should-know
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/what-is-parkinsons/stages
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/what-is-parkinsons/related-conditions
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/cognitive
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/movement-symptoms/facial-masking
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/incontinence
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/what-is-parkinsons/types-parkinsonisms
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/movement-symptoms/postural-instability
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/fatigue
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/movement-symptoms/bradykinesia
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/bone-health
#   Crawling (depth 2): https://www.parkinson.org/library/fact-sheets/pain
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/constipation
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/statistics/prevalence-incidence
#   Crawling (depth 2): https://www.parkinson.org/understanding-parkinsons/non-movement-symptoms/hallucinations-delusions
#   Crawling (depth 2): https://www.parkinson.org/blog/awareness/top-pam-videos
# Crawling Michael J. Fox Foundation...
#   Crawling (depth 0): https://www.michaeljfox.org/
#   Crawling (depth 1): https://www.michaeljfox.org/news/ask-md-next-generation-dbs-here
#   Crawling (depth 1): https://www.michaeljfox.org/our-impact
#   Crawling (depth 1): https://www.michaeljfox.org/news/michael-j-fox-announces-new-memoir-future-boy-be-published-fall
#   Crawling (depth 1): https://www.michaeljfox.org/symptoms
#   Crawling (depth 1): https://www.michaeljfox.org/conociendo-la-enfermedad-de-parkinson
#   Crawling (depth 1): https://www.michaeljfox.org/contact-your-policymakers
#   Crawling (depth 1): https://www.michaeljfox.org/scientific-publications
#   Crawling (depth 1): https://www.michaeljfox.org/your-role-parkinsons-research
#   Crawling (depth 1): https://www.michaeljfox.org/working-us
#   Crawling (depth 1): https://www.michaeljfox.org/parkinsons-360
#   Crawling (depth 1): https://www.michaeljfox.org/funded-studies
#   Crawling (depth 1): https://www.michaeljfox.org/samllogin
#   Crawling (depth 1): https://www.michaeljfox.org/node/57196
# HTTP 403 for https://www.michaeljfox.org/node/57196
#   Crawling (depth 1): https://www.michaeljfox.org/be-fundraiser
#   Crawling (depth 1): https://www.michaeljfox.org/user/logout
#   Crawling (depth 1): https://www.michaeljfox.org/our-public-policy-priorities
#   Crawling (depth 1): https://www.michaeljfox.org/do-it-yourself
#   Crawling (depth 1): https://www.michaeljfox.org/research-news
#   Crawling (depth 1): https://www.michaeljfox.org/mental-physical-health
#   Crawling (depth 1): https://www.michaeljfox.org/funding-opportunities
#   Crawling (depth 1): https://www.michaeljfox.org/news/what-we-fund-606m-tools-detect-pd-and-therapies-treat-it
#   Crawling (depth 1): https://www.michaeljfox.org/glossary-terms
#   Crawling (depth 1): https://www.michaeljfox.org/faq
#   Crawling (depth 1): https://www.michaeljfox.org/webinar/finding-right-tech-tools-your-parkinsons-journey
#   Crawling (depth 1): https://www.michaeljfox.org/current-partnerships
#   Crawling (depth 1): https://www.michaeljfox.org/ask-md
#   Crawling (depth 1): https://www.michaeljfox.org/real-talk-patients
#   Crawling (depth 1): https://www.michaeljfox.org/podcast/building-your-best-parkinsons-care-team-webinar-audio
#   Crawling (depth 1): https://www.michaeljfox.org/podcast
#   Crawling (depth 1): https://www.michaeljfox.org/news/drug-potential-slow-or-stop-parkinsons-moves-next-phase-clinical-testing
#   Crawling (depth 1): https://www.michaeljfox.org/work-benefits
#   Crawling (depth 1): https://www.michaeljfox.org/our-agenda
#   Crawling (depth 1): https://www.michaeljfox.org/webinars
#   Crawling (depth 1): https://www.michaeljfox.org/library
#   Crawling (depth 1): https://www.michaeljfox.org/national-parkinsons-project
#   Crawling (depth 1): https://www.michaeljfox.org/news/watch-jimmy-choi-inspire-millions-and-achieve-new-personal-record-american-ninja-warrior
#   Crawling (depth 1): https://www.michaeljfox.org/give-tribute
#   Crawling (depth 1): https://www.michaeljfox.org/join-study
#   Crawling (depth 1): https://www.michaeljfox.org/related-conditions
#   Crawling (depth 1): https://www.michaeljfox.org/our-research-strategy
#   Crawling (depth 1): https://www.michaeljfox.org/prizes
#   Crawling (depth 1): https://www.michaeljfox.org/parkinsons-iq-you
#   Crawling (depth 1): https://www.michaeljfox.org/build-connections-parkinsons-buddy-network
#   Crawling (depth 1): https://www.michaeljfox.org/contact-us
#   Crawling (depth 1): https://www.michaeljfox.org/study-recruitment
#   Crawling (depth 1): https://www.michaeljfox.org/corporate-giving
#   Crawling (depth 1): https://www.michaeljfox.org/news/what-we-fund-497m-supports-parkinsons-biology-insights-and-more
#   Crawling (depth 1): https://www.michaeljfox.org/privacy-policy
#   Crawling (depth 1): https://www.michaeljfox.org/past-annual-reports
#   Crawling (depth 1): https://www.michaeljfox.org/parkinsons-biomarkers
#   Crawling (depth 1): https://www.michaeljfox.org/ways-to-give
#   Crawling (depth 1): https://www.michaeljfox.org/real-talk-participants
#   Crawling (depth 1): https://www.michaeljfox.org/foundation-leadership
#   Crawling (depth 1): https://www.michaeljfox.org/find-fundraiser-or-event
#   Crawling (depth 1): https://www.michaeljfox.org/news/advancing-parkinsons-research-through-patient-centered-approach
#   Crawling (depth 1): https://www.michaeljfox.org/webinar/plan-purpose-your-estate-plan-after-parkinsons-diagnosis
#   Crawling (depth 1): https://www.michaeljfox.org/state-field
#   Crawling (depth 1): https://www.michaeljfox.org/press-releases
#   Crawling (depth 1): https://www.michaeljfox.org/mjff-news
#   Crawling (depth 1): https://www.michaeljfox.org/data-resources
#   Crawling (depth 1): https://www.michaeljfox.org/2019-2020-annual-report-milestones-and-momentum
#   Crawling (depth 1): https://www.michaeljfox.org/news/tracers-development-newly-installed-pet-camera-signal-advancement-parkinsons-imaging
#   Crawling (depth 1): https://www.michaeljfox.org/research-tools
#   Crawling (depth 1): https://www.michaeljfox.org/sitemap.xml
# /tmp/ipython-input-13-265431243.py:85: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(response.content, 'html.parser')
# /tmp/ipython-input-13-265431243.py:417: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   soup = BeautifulSoup(response.content, 'html.parser')
#   Crawling (depth 1): https://www.michaeljfox.org/michaels-story
#   Crawling (depth 1): https://www.michaeljfox.org/mjff-feed
#   Crawling (depth 1): https://www.michaeljfox.org/team-fox-endurance
#   Crawling (depth 1): https://www.michaeljfox.org/medications-treatments
#   Crawling (depth 1): https://www.michaeljfox.org/causes
#   Crawling (depth 1): https://www.michaeljfox.org/books-resources
#   Crawling (depth 1): https://www.michaeljfox.org/publications
#   Crawling (depth 1): https://www.michaeljfox.org/biospecimens
#   Crawling (depth 1): https://www.michaeljfox.org/updates-washington
#   Crawling (depth 1): https://www.michaeljfox.org/advocacy-resources
#   Crawling (depth 1): https://www.michaeljfox.org/asap
#   Crawling (depth 1): https://www.michaeljfox.org/key-research-initiatives
#   Crawling (depth 1): https://www.michaeljfox.org/our-commitment-research-integrity
#   Crawling (depth 1): https://www.michaeljfox.org/ppmi
#   Crawling (depth 1): https://www.michaeljfox.org/what-we-fund
#   Crawling (depth 1): https://www.michaeljfox.org/trial-finder
#   Crawling (depth 1): https://www.michaeljfox.org/resources-people-newly-diagnosed-parkinsons
#   Crawling (depth 1): https://www.michaeljfox.org/building-care-team
#   Crawling (depth 1): https://www.michaeljfox.org/podcast/understanding-experience-lgbtq-people-living-parkinsons-disease
#   Crawling (depth 1): https://www.michaeljfox.org/relationships
#   Crawling (depth 1): https://www.michaeljfox.org/collaborative-research-opportunities
#   Crawling (depth 1): https://www.michaeljfox.org/ppmi-clinical-study
#   Crawling (depth 1): https://www.michaeljfox.org/user/0/edit
# HTTP 403 for https://www.michaeljfox.org/user/0/edit
#   Crawling (depth 1): https://www.michaeljfox.org/state-nonprofit-disclosures
#   Crawling (depth 1): https://www.michaeljfox.org/news/leading-parkinsons-advocacy-groups-urge-strong-federal-investment-biomedical-research
#   Crawling (depth 1): https://www.michaeljfox.org/terms-conditions
#   Crawling (depth 1): https://www.michaeljfox.org/news/early-onset-parkinsons-disease
#   Crawling (depth 1): https://www.michaeljfox.org/our-promise
#   Crawling (depth 1): https://www.michaeljfox.org/news/runwalk-and-cycling-series
#   Crawling (depth 1): https://www.michaeljfox.org/careers
#   Crawling (depth 1): https://www.michaeljfox.org/parkinsons-101
#   Crawling (depth 1): https://www.michaeljfox.org/fundraiser-resources
#   Crawling (depth 1): https://www.michaeljfox.org/news/parkinsons-same-parkinsonism-ask-md-video
#   Crawling (depth 1): https://www.michaeljfox.org/foundation-updates
#   Crawling (depth 1): https://www.michaeljfox.org/news/research-roundup-join-studies-aiming-treat-parkinsons-progression
# Crawling American Parkinson Disease Association...
#   Crawling (depth 0): https://www.apdaparkinson.org/
#   Crawling (depth 1): https://www.apdaparkinson.org/about-apda
#   Crawling (depth 1): https://www.apdaparkinson.org/living-with-parkinsons-disease
#   Crawling (depth 1): https://www.apdaparkinson.org/news
#   Crawling (depth 1): https://www.apdaparkinson.org/what-is-parkinsons
#   Crawling (depth 1): https://www.apdaparkinson.org/living-with-parkinsons-disease/relationships
#   Crawling (depth 1): https://www.apdaparkinson.org/doctor-blogs/a-closer-look
#   Crawling (depth 1): https://www.apdaparkinson.org/events/thriving-through-occupational-therapy-living-well-with-parkinsons-fatigue
#   Crawling (depth 1): https://www.apdaparkinson.org/research/advanced-centers
#   Crawling (depth 1): https://www.apdaparkinson.org/living-with-parkinsons-disease/treatment-medication
#   Crawling (depth 1): https://www.apdaparkinson.org/research
#   Crawling (depth 1): https://www.apdaparkinson.org/what-is-parkinsons/symptoms
#   Crawling (depth 1): https://www.apdaparkinson.org/get-involved/memorial-and-tribute-gifts
#   Crawling (depth 1): https://www.apdaparkinson.org/article/neuromodulation-for-parkinsons-disease
#   Crawling (depth 1): https://www.apdaparkinson.org/resources-support/rehab-resource-center
#   Crawling (depth 1): https://www.apdaparkinson.org/article/nanocarrier-breakthrough-offers-hope-for-pd-treatment
#   Crawling (depth 1): https://www.apdaparkinson.org/disclosure-statement
#   Crawling (depth 1): https://www.apdaparkinson.org/resources
#   Crawling (depth 1): https://www.apdaparkinson.org/research/research-opportunities
#   Crawling (depth 1): https://www.apdaparkinson.org/research/what-we-fund
#   Crawling (depth 1): https://www.apdaparkinson.org/upcoming-events
#   Crawling (depth 1): https://www.apdaparkinson.org/resources-support/en-espanol
#   Crawling (depth 1): https://www.apdaparkinson.org/1907d3l
#   Crawling (depth 1): https://www.apdaparkinson.org/what-is-parkinsons/diagnosing
#   Crawling (depth 1): https://www.apdaparkinson.org/resources-support
#   Crawling (depth 1): https://www.apdaparkinson.org/research/clinical-trials
#   Crawling (depth 1): https://www.apdaparkinson.org/resources-support/download-publications
#   Crawling (depth 1): https://www.apdaparkinson.org/about-apda/financial-reports
#   Crawling (depth 1): https://www.apdaparkinson.org/events/dr-gilbert-hosts-climate-weather-parkinsons-disease
#   Crawling (depth 1): https://www.apdaparkinson.org/professional-training-courses
#   Crawling (depth 1): https://www.apdaparkinson.org/about-apda/strategic-plan
#   Crawling (depth 1): https://www.apdaparkinson.org/what-is-parkinsons/causes
#   Crawling (depth 1): https://www.apdaparkinson.org/champion
#   Crawling (depth 1): https://www.apdaparkinson.org/what-is-parkinsons/early-onset-parkinsons-disease
#   Crawling (depth 1): https://www.apdaparkinson.org/community
#   Crawling (depth 1): http://www.apdaparkinson.org/research
#   Crawling (depth 1): https://www.apdaparkinson.org/get-involved/optimism-walks
#   Crawling (depth 1): https://www.apdaparkinson.org/terms-of-use
#   Crawling (depth 1): https://www.apdaparkinson.org/living-with-parkinsons-disease/diet-nutrition
#   Crawling (depth 1): http://www.apdaparkinson.org/get-involved/ways-to-give
#   Crawling (depth 1): https://www.apdaparkinson.org/donor-policy
#   Crawling (depth 1): https://www.apdaparkinson.org/living-with-parkinsons-disease/mental-health
#   Crawling (depth 1): http://www.apdaparkinson.org/what-is-parkinsons
#   Crawling (depth 1): https://www.apdaparkinson.org/about-apda/career-opportunities
#   Crawling (depth 1): https://www.apdaparkinson.org/living-with-parkinsons-disease/exercise
#   Crawling (depth 1): https://www.apdaparkinson.org/resources-support/for-caregivers
#   Crawling (depth 1): https://www.apdaparkinson.org/apda-symptom-tracker
#   Crawling (depth 1): http://www.apdaparkinson.org/resources-support/living-with-parkinsons-disease
# HTTP 404 for http://www.apdaparkinson.org/resources-support/living-with-parkinsons-disease
#   Crawling (depth 1): https://www.apdaparkinson.org/get-involved/diy-fundraising
#   Crawling (depth 1): https://www.apdaparkinson.org/get-involved/ways-to-give
#   Crawling (depth 1): https://www.apdaparkinson.org/newly-diagnosed
#   Crawling (depth 1): https://www.apdaparkinson.org/privacy-policy
#   Crawling (depth 1): https://www.apdaparkinson.org/living-with-parkinsons-disease/treatment-medication/medication
#   Crawling (depth 1): https://www.apdaparkinson.org/article/a-new-blood-test-could-identify-parkinsons-disease-before-symptoms-appear
#   Crawling (depth 1): https://www.apdaparkinson.org/contact
#   Crawling (depth 1): https://www.apdaparkinson.org
#   Crawling (depth 1): https://www.apdaparkinson.org/living-with-parkinsons-disease/disability
#   Crawling (depth 1): https://www.apdaparkinson.org/article/parkinsons-research-insights-dr-greenamyre
#   Crawling (depth 2): http://www.apdaparkinson.org
#   Crawling (depth 2): https://www.apdaparkinson.org/about-apda/eloise-caggiano
#   Crawling (depth 2): https://www.apdaparkinson.org/about-apda/rosa-pena
#   Crawling (depth 2): https://www.apdaparkinson.org/about-apda/chris-salicco
#   Crawling (depth 2): https://www.apdaparkinson.org/core-values
#   Crawling (depth 2): https://www.apdaparkinson.org/about-apda/scientific-advisory-board
#   Crawling (depth 2): https://www.apdaparkinson.org/about-apda/heather-hays
#   Crawling (depth 2): https://www.apdaparkinson.org/about-apda/leslie-a-chambers
#   Crawling (depth 2): https://www.apdaparkinson.org/about-apda/michelle-h-mcdonald
#   Crawling (depth 2): https://www.apdaparkinson.org/about-apda/david-g-standaert-md-phd
#   Crawling (depth 2): https://www.apdaparkinson.org/about-apda/rebecca-gilbert-md-phd
#   Crawling (depth 2): https://www.apdaparkinson.org/resources-support/living-with-parkinsons-disease/exercise
#   Crawling (depth 2): https://www.apdaparkinson.org/resources-support/living-with-parkinsons-disease/diet-nutrition
#   Crawling (depth 2): https://www.apdaparkinson.org/resources-support/living-with-parkinsons-disease/disability
#   Crawling (depth 2): https://www.apdaparkinson.org/pdtheessentials
#   Crawling (depth 2): https://www.apdaparkinson.org/what-is-parkinsons/treatment-medication
# HTTP 404 for https://www.apdaparkinson.org/what-is-parkinsons/treatment-medication
#   Crawling (depth 2): https://www.apdaparkinson.org/resources-support/educational-video-library
#   Crawling (depth 2): https://www.apdaparkinson.org/resources-support/local-resources
#   Crawling (depth 2): https://www.apdaparkinson.org/news/apda-in-the-news
# HTTP 404 for https://www.apdaparkinson.org/news/apda-in-the-news
#   Crawling (depth 2): https://www.apdaparkinson.org/news/newsletter-archive
# HTTP 404 for https://www.apdaparkinson.org/news/newsletter-archive
#   Crawling (depth 2): https://www.apdaparkinson.org/article/fda-approves-new-adaptive-dbs-system
#   Crawling (depth 2): https://www.apdaparkinson.org/article/american-parkinson-disease-association-free-two-day-virtual-conference-returns-to-educate-empower-and-engage-the-pd-communit
#   Crawling (depth 2): https://www.apdaparkinson.org/news/breaking-news
# HTTP 404 for https://www.apdaparkinson.org/news/breaking-news
#   Crawling (depth 2): https://www.apdaparkinson.org/news/press-releases
# HTTP 404 for https://www.apdaparkinson.org/news/press-releases
#   Crawling (depth 2): https://www.apdaparkinson.org/article/american-parkinson-disease-association-to-educate-and-empower-during-parkinsons-disease-awareness-month
#   Crawling (depth 2): https://www.apdaparkinson.org/article/american-parkinson-disease-association-kicks-off-2025-optimism-walk-series
#   Crawling (depth 2): https://www.apdaparkinson.org/article/joining-forces-to-push-for-federal-research-funding
#   Crawling (depth 2): https://www.apdaparkinson.org/apda-in-the-news
#   Crawling (depth 2): https://www.apdaparkinson.org/article/golf-course-concerns-new-research-shows-link-to-parkinsons
#   Crawling (depth 2): https://www.apdaparkinson.org/article/american-parkinson-disease-association-welcomes-two-accomplished-leaders-to-national-board-of-directors
#   Crawling (depth 2): https://www.apdaparkinson.org/what-is-parkinsons/symptoms/sleep-problems
#   Crawling (depth 2): https://www.apdaparkinson.org/what-is-parkinsons/symptoms/tremor
#   Crawling (depth 2): https://www.apdaparkinson.org/what-is-parkinsons/symptoms/fatigue
#   Crawling (depth 2): https://www.apdaparkinson.org/article/new-laboratory-tests-for-parkinsons-disease
#   Crawling (depth 2): https://www.apdaparkinson.org/article/genetic-testing-for-parkinsons-disease
#   Crawling (depth 2): https://www.apdaparkinson.org/videos/138935
#   Crawling (depth 2): https://www.apdaparkinson.org/article/what-is-a-datscan-and-should-i-get-one
#   Crawling (depth 2): https://www.apdaparkinson.org/resources-support/living-with-parkinsons-disease
# HTTP 404 for https://www.apdaparkinson.org/resources-support/living-with-parkinsons-disease
#   Crawling (depth 2): https://www.apdaparkinson.org/what-is-parkinsons/symptoms/depression
#   Crawling (depth 2): https://www.apdaparkinson.org/article/building-your-parkinsons-care-team
#   Crawling (depth 2): https://www.apdaparkinson.org/article/the-gut-and-parkinsons
#   Crawling (depth 2): https://www.apdaparkinson.org/article/the-relationship-between-pesticides-and-parkinsons
# Crawling Parkinson Canada...
#   Crawling (depth 0): https://www.parkinson.ca/
#   Crawling (depth 1): https://www.parkinson.ca/parkinsons-iq-you
#   Crawling (depth 1): https://www.parkinson.ca/about-us/leadership-team
#   Crawling (depth 1): https://www.parkinson.ca/fr
#   Crawling (depth 1): https://www.parkinson.ca/home/living-better/newly-diagnosed/how-to-tell-people
#   Crawling (depth 1): https://www.parkinson.ca/home/living-better/newly-diagnosed/managing-stigma
#   Crawling (depth 1): https://www.parkinson.ca/research/research-goals
#   Crawling (depth 1): https://www.parkinson.ca/how-mime-over-mind-is-transforming-lives-through-creativity
#   Crawling (depth 1): https://www.parkinson.ca/get-involved
#   Crawling (depth 1): https://www.parkinson.ca/about-us/accountability/complaints-policy-and-procedure
#   Crawling (depth 1): https://www.parkinson.ca/get-involved/careers
#   Crawling (depth 1): https://www.parkinson.ca/home/living-better/staying-active
#   Crawling (depth 1): https://www.parkinson.ca/what-is-parkinsons/progression
#   Crawling (depth 1): https://www.parkinson.ca/care-finder
#   Crawling (depth 1): https://www.parkinson.ca/what-is-parkinsons/atypical-parkinsonisms
#   Crawling (depth 1): https://www.parkinson.ca/home/living-better
#   Crawling (depth 1): https://www.parkinson.ca/about-us/contact-us
#   Crawling (depth 1): https://www.parkinson.ca/research/apply-for-funding
#   Crawling (depth 1): https://www.parkinson.ca/peer-support-program
#   Crawling (depth 1): https://www.parkinson.ca/gait-challenges-in-parkinsons-new-research-directions
#   Crawling (depth 1): https://www.parkinson.ca/about-us
#   Crawling (depth 1): https://www.parkinson.ca/what-is-parkinsons/early-onset
#   Crawling (depth 1): https://www.parkinson.ca/resources/support-groups
#   Crawling (depth 1): https://www.parkinson.ca/what-is-parkinsons/motor-symptoms
#   Crawling (depth 1): https://www.parkinson.ca
#   Crawling (depth 1): https://www.parkinson.ca/get-involved/personal-giving
#   Crawling (depth 1): https://www.parkinson.ca/privacy-policy
#   Crawling (depth 1): https://www.parkinson.ca/get-involved/moment-maker
#   Crawling (depth 1): https://www.parkinson.ca/about-us/accountability
#   Crawling (depth 1): https://www.parkinson.ca/terms-and-conditions
#   Crawling (depth 1): https://www.parkinson.ca/home/living-better/newly-diagnosed
#   Crawling (depth 1): https://www.parkinson.ca/research/funded-research
#   Crawling (depth 1): https://www.parkinson.ca/home/living-better/care-partners
#   Crawling (depth 1): https://www.parkinson.ca/get-involved/volunteer
#   Crawling (depth 1): https://www.parkinson.ca/care-fund
#   Crawling (depth 1): https://www.parkinson.ca/home/living-better/build-your-team
#   Crawling (depth 1): https://www.parkinson.ca/what-is-parkinsons
#   Crawling (depth 1): https://www.parkinson.ca/research/canadian-open-parkinson-network
#   Crawling (depth 1): https://www.parkinson.ca/research
#   Crawling (depth 1): https://www.parkinson.ca/resources/blog
#   Crawling (depth 1): https://www.parkinson.ca/dr-google-and-how-to-spot-parkinsons-misinformation
#   Crawling (depth 1): https://www.parkinson.ca/what-is-parkinsons/non-motor-symptoms
#   Crawling (depth 1): https://www.parkinson.ca/research/for-researchers
#   Crawling (depth 1): https://www.parkinson.ca/about-us/media
#   Crawling (depth 1): https://www.parkinson.ca/about-us/strategic-plan
#   Crawling (depth 1): https://www.parkinson.ca/about-us/mission-vision-values
#   Crawling (depth 1): https://www.parkinson.ca/resources
#   Crawling (depth 1): https://www.parkinson.ca/about-us/financial-and-impact-reports
#   Crawling (depth 1): https://www.parkinson.ca/resources/support-line
#   Crawling (depth 1): https://www.parkinson.ca/research/new-in-research
#   Crawling (depth 1): https://www.parkinson.ca/resources/community-events-and-webinars
#   Crawling (depth 1): https://www.parkinson.ca/what-is-parkinsons/treatments
#   Crawling (depth 1): https://www.parkinson.ca/resources/educational-publications/every-victory-counts-canadian-edition
#   Crawling (depth 1): https://www.parkinson.ca/home/living-better/women
#   Crawling (depth 1): https://www.parkinson.ca/resources/educational-publications
#   Crawling (depth 1): https://www.parkinson.ca/get-involved/fundraising-events
#   Crawling (depth 2): https://www.parkinson.ca/fr/parkinsons-iq-you
#   Crawling (depth 2): https://www.parkinson.ca/fr/a-propos-de-nous/equipe-de-direction
#   Crawling (depth 2): https://www.parkinson.ca/about-us/board-of-directors
#   Crawling (depth 2): https://www.parkinson.ca/about-us/research-and-clinical-advisory-committee
#   Crawling (depth 2): https://www.parkinson.ca/about-us/advisory-council
#   Crawling (depth 2): https://www.parkinson.ca/fr/facons-de-donner/don-personnel
#   Crawling (depth 2): https://www.parkinson.ca/fr/prasinezumab-un-medicament-prometteur-contre-la-maladie-de-parkinson-entre-dans-la-phase-suivante-des-essais-cliniques
#   Crawling (depth 2): https://www.parkinson.ca/fr/ressources/ligne-de-soutien-pour-la-maladie-de-parkinson
#   Crawling (depth 2): https://www.parkinson.ca/fr/quest-ce-que-la-maladie-de-parkinson/debut-de-la-maladie
#   Crawling (depth 2): https://www.parkinson.ca/fr/facons-de-donner/evenements-de-collecte-de-fonds
#   Crawling (depth 2): https://www.parkinson.ca/fr/recherche/reseau-canadien-ouvert-de-la-maladie-de-parkinson
#   Crawling (depth 2): https://www.parkinson.ca/fr/quest-ce-que-la-maladie-de-parkinson
#   Crawling (depth 2): https://www.parkinson.ca/fr/facons-de-donner/opportunites-de-carriere
#   Crawling (depth 2): https://www.parkinson.ca/fr/home/mieux-vivre-avec-la-maladie-de-parkinson/rester-actif
#   Crawling (depth 2): https://www.parkinson.ca/fr/a-propos-de-nous/mission-vision-valeurs
#   Crawling (depth 2): https://www.parkinson.ca/fr/a-propos-de-nous/rapports-financiers-et-dimpact
#   Crawling (depth 2): https://www.parkinson.ca/fr/recherche/objectifs-de-la-recherche
#   Crawling (depth 2): https://www.parkinson.ca/fr/recherche/pour-les-chercheurs
#   Crawling (depth 2): https://www.parkinson.ca/fr/home/mieux-vivre-avec-la-maladie-de-parkinson/diagnostic-recent-de-la-maladie-de-parkinson
#   Crawling (depth 2): https://www.parkinson.ca/fr/home/mieux-vivre-avec-la-maladie-de-parkinson/les-femmes-et-la-maladie-de-parkinson
#   Crawling (depth 2): https://www.parkinson.ca/fr/quest-ce-que-la-maladie-de-parkinson/traitements-de-la-maladie-de-parkinson
#   Crawling (depth 2): https://www.parkinson.ca/fr/ressources/publications-educatives
#   Crawling (depth 2): https://www.parkinson.ca/fr/quest-ce-que-la-maladie-de-parkinson/symptomes-non-moteurs
#   Crawling (depth 2): https://www.parkinson.ca/fr/ressources/evenements-communautaires-et-webinaires
#   Crawling (depth 2): https://www.parkinson.ca/fr/a-propos-de-nous/salle-des-medias
#   Crawling (depth 2): https://www.parkinson.ca/fr/programme-de-soutien-par-les-pairs
#   Crawling (depth 2): https://www.parkinson.ca/fr/ressources/groupes-de-soutien
#   Crawling (depth 2): https://www.parkinson.ca/fr/defense-des-interests
#   Crawling (depth 2): https://www.parkinson.ca/fr/facons-de-donner/createur-de-moments
#   Crawling (depth 2): https://www.parkinson.ca/fr/clinial-trial
#   Crawling (depth 2): https://www.parkinson.ca/fr/ressources
#   Crawling (depth 2): https://www.parkinson.ca/fr/home/mieux-vivre-avec-la-maladie-de-parkinson/constituez-votre-equipe
#   Crawling (depth 2): https://www.parkinson.ca/fr/home/mieux-vivre-avec-la-maladie-de-parkinson/fournir-des-soins
#   Crawling (depth 2): https://www.parkinson.ca/fr/facons-de-donner
#   Crawling (depth 2): https://www.parkinson.ca/fr/quest-ce-que-la-maladie-de-parkinson/parkinsonismes-atypiques
#   Crawling (depth 2): https://www.parkinson.ca/fr/recherche/recherche-financee
#   Crawling (depth 2): https://www.parkinson.ca/fr/a-propos-de-nous/plan-strategique
#   Crawling (depth 2): https://www.parkinson.ca/fr/a-propos-de-nous/responsabilite
#   Crawling (depth 2): https://www.parkinson.ca/fr/home/mieux-vivre-avec-la-maladie-de-parkinson
#   Crawling (depth 2): https://www.parkinson.ca/fr/defis-de-la-marche-dans-la-maladie-de-parkinson-nouvelles-orientations-de-la-recherche
#   Crawling (depth 2): https://www.parkinson.ca/fr/home/mieux-vivre-avec-la-maladie-de-parkinson/diagnostic-recent-de-la-maladie-de-parkinson/gerer-la-stigmatisation
#   Crawling (depth 2): https://www.parkinson.ca/fr/a-propos-de-nous
#   Crawling (depth 2): https://www.parkinson.ca/fr/ressources/publications-educatives/chaque-victoire-compte-edition-canadienne
#   Crawling (depth 2): https://www.parkinson.ca/fr/comment-mime-over-mind-transforme-des-vies-grace-a-la-creativite
# Crawling European Parkinson's Disease Association...
#   Crawling (depth 0): https://parkinsonseurope.org/
# HTTP 403 for https://parkinsonseurope.org/
# Crawling Parkinson's UK...
#   Crawling (depth 0): https://www.parkinsons.org.uk/
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/benefits-working-us
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/parkinsons-virtual-biotech
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/local-groups
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/resources/helping-healthcare-professionals-share-research-patients
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/fundraising
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/therapies-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/order-fundraising-guide
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/resources/time-critical-medication-and-get-it-time-campaign-resources
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/corporate-fundraising
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/feedback-and-complaints
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/young-onset-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/media-and-press-office
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/parkinsons-learning-pathway-pharmacy-professionals
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/terms-and-conditions
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/parkinsons-nurses
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/privacy-policy
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/volunteer-parkinsons-uk
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/helpline-and-parkinsons-advisers
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/your-magazine
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/support-research-breakthroughs
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/parkinsons-uk-northern-ireland
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/side-effects-parkinsons-drugs
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/resources-and-support-researchers
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/give-memory
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/what-we-do
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/supporter-enquiries
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/when-will-there-be-cure-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/newly-diagnosed-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/parkinsons-excellence-network-awards
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/supporting-someone-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/resources
#   Crawling (depth 1): https://www.parkinsons.org.uk
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/local-parkinsons-excellence-networks-and-excellence-hubs
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/relationships-and-family-life
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/do-your-own-fundraising
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/what-we-think
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/research-volunteering-opportunities
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/parkinsons-researchers
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/our-research-projects
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/general-enquiries
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/learning-hub
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/does-parkinsons-run-families
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/deep-brain-stimulation
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/membership
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/uk-parkinsons-audit-transforming-care
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/parkinsons-drugs
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/parkinsons-symptoms
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/types-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/get-involved-research
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/work-money-driving-and-legal-rights-when-you-have-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/living-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/news
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/funding-opportunities
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/research-blog
#   Crawling (depth 1): https://www.parkinsons.org.uk/news
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/campaigning-change
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/join-team-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/where-your-money-goes
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/most-popular-resources-your-patients
#   Crawling (depth 1): https://www.parkinsons.org.uk/contact
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/agm
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/volunteering-roles
#   Crawling (depth 1): https://www.parkinsons.org.uk/news/news-topics/research
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/our-health-and-social-care-campaigns
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/treatments-and-therapies-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/volunteer-induction
#   Crawling (depth 1): https://www.parkinsons.org.uk/cdn-cgi/l/email-protection
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/how-send-us-your-fundraising
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/information-your-patients
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/parkinsons-learning-pathway-health-care-staff
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/parkinsons-and-mental-health
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/our-support-services
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/our-strategy
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/assemble-user-guide
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/motor-symptoms-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/jobs-parkinsons-uk
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/volunteer-resources
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/non-motor-symptoms-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/parkinsons-therapist-learning-pathway
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/parkinsons-uk-excellence-network
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/what-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/clinical-tools-and-assessments
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/research-events
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/how-does-parkinsons-progress
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/patient-and-public-involvement-research
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/events-and-learning
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/sign-parky-charter
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/everyday-life
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/explore-our-research
#   Crawling (depth 1): https://www.parkinsons.org.uk/information-and-support/what-causes-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/make-benefits-work-people-parkinsons
#   Crawling (depth 1): https://www.parkinsons.org.uk/professionals/resources-professionals
#   Crawling (depth 1): https://www.parkinsons.org.uk/events
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/become-member
#   Crawling (depth 1): https://www.parkinsons.org.uk/about-us/cookies-policy
#   Crawling (depth 1): https://www.parkinsons.org.uk/get-involved/parkinsons-uk-parliament
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/staying-connected-your-participants
#   Crawling (depth 1): https://www.parkinsons.org.uk/research/our-research-impact
# Crawling Davis Phinney Foundation...
#   Crawling (depth 0): https://davisphinneyfoundation.org/
# HTTP 403 for https://davisphinneyfoundation.org/
# Crawling PMD Alliance...
#   Crawling (depth 0): https://www.pmdalliance.org/
#   Crawling (depth 1): https://www.pmdalliance.org/board-members
#   Crawling (depth 1): https://www.pmdalliance.org/medication-access
#   Crawling (depth 1): https://www.pmdalliance.org/impactful-information
#   Crawling (depth 1): https://www.pmdalliance.org/contact-us
#   Crawling (depth 1): https://www.pmdalliance.org/make-an-impact/ways-to-build-a-legacy
#   Crawling (depth 1): https://www.pmdalliance.org/recently-diagnosed
#   Crawling (depth 1): https://www.pmdalliance.org/news
#   Crawling (depth 1): https://www.pmdalliance.org/careers
#   Crawling (depth 1): https://www.pmdalliance.org/ecosystem
#   Crawling (depth 1): https://www.pmdalliance.org/all-in-summit
#   Crawling (depth 1): https://www.pmdalliance.org/resources
#   Crawling (depth 1): https://www.pmdalliance.org/clinical-partners
#   Crawling (depth 1): https://www.pmdalliance.org/community-partners
#   Crawling (depth 1): https://www.pmdalliance.org/staff
#   Crawling (depth 1): https://www.pmdalliance.org/my-pd-care
#   Crawling (depth 1): https://www.pmdalliance.org/featured-support-groups
#   Crawling (depth 1): https://www.pmdalliance.org/privacy-policy
#   Crawling (depth 1): https://www.pmdalliance.org/events
#   Crawling (depth 1): https://www.pmdalliance.org/treatmentoptions/themoreyouknow
#   Crawling (depth 1): https://www.pmdalliance.org/ways-to-donate
#   Crawling (depth 1): https://www.pmdalliance.org/yopd
#   Crawling (depth 1): https://www.pmdalliance.org/about
#   Crawling (depth 1): https://www.pmdalliance.org/treatmentoptions/medication
#   Crawling (depth 1): https://www.pmdalliance.org/margaret-tuchman-library
#   Crawling (depth 1): https://www.pmdalliance.org/care-partners-family-members-adult-children
#   Crawling (depth 1): https://www.pmdalliance.org/sabes
#   Crawling (depth 1): https://www.pmdalliance.org/make-an-impact/impactful-information
#   Crawling (depth 1): https://www.pmdalliance.org/realtalk
#   Crawling (depth 1): https://www.pmdalliance.org/la-comision-asesora-para-parkinson
#   Crawling (depth 1): https://www.pmdalliance.org/partnerships
#   Crawling (depth 1): https://www.pmdalliance.org/person-with-movement-disorder
#   Crawling (depth 1): https://www.pmdalliance.org/resources/national-regional-local
#   Crawling (depth 1): https://www.pmdalliance.org/treatmentoptions
#   Crawling (depth 1): https://www.pmdalliance.org/empowered-tool
#   Crawling (depth 1): https://www.pmdalliance.org/about-us
#   Crawling (depth 1): https://www.pmdalliance.org/healthcare-providers
#   Crawling (depth 1): https://www.pmdalliance.org/industry-partners
#   Crawling (depth 1): https://www.pmdalliance.org/missionvisionandvalues
#   Crawling (depth 1): https://www.pmdalliance.org/support-group-leader
#   Crawling (depth 1): https://www.pmdalliance.org/cpdc
#   Crawling (depth 1): https://www.pmdalliance.org/volunteer
# HTTP 404 for https://www.pmdalliance.org/volunteer
#   Crawling (depth 1): https://www.pmdalliance.org/treatmentoptions/device-aided-therapies
#   Crawling (depth 1): https://www.pmdalliance.org/give
#   Crawling (depth 1): https://www.pmdalliance.org/press-room
#   Crawling (depth 1): https://www.pmdalliance.org/neuro-life-online-video-library
#   Crawling (depth 1): https://www.pmdalliance.org/certified-parkinson-disease-care-facilities
#   Crawling (depth 1): https://www.pmdalliance.org
#   Crawling (depth 1): https://www.pmdalliance.org/ambassadors
#   Crawling (depth 1): https://www.pmdalliance.org/campfire
#   Crawling (depth 2): https://www.pmdalliance.org/about/board-members
#   Crawling (depth 2): https://www.pmdalliance.org/about/ecosystem
#   Crawling (depth 2): https://www.pmdalliance.org/about/ambassadors
#   Crawling (depth 2): https://www.pmdalliance.org/make-an-impact/impactful-information/form-990
#   Crawling (depth 2): https://www.pmdalliance.org/make-an-impact/impactful-information/quarterly-impact-reports
#   Crawling (depth 2): https://www.pmdalliance.org/impactful-information/annualreports
#   Crawling (depth 2): https://www.pmdalliance.org/make-an-impact/impactful-information/donor-bill-of-rights
#   Crawling (depth 2): https://www.pmdalliance.org/2025/04/30/yoga-manual-for-pd
#   Crawling (depth 2): https://www.pmdalliance.org/2025/06/10/tiktok-yopd-community
#   Crawling (depth 2): https://www.pmdalliance.org/news/page/3
#   Crawling (depth 2): https://www.pmdalliance.org/2025/04/30/space-for-pd-care-partners
#   Crawling (depth 2): https://www.pmdalliance.org/2025/06/18/10-ice-cold-summer-beverages
#   Crawling (depth 2): https://www.pmdalliance.org/news/page/32
#   Crawling (depth 2): https://www.pmdalliance.org/2025/06/04/10-parkinsons-books
#   Crawling (depth 2): https://www.pmdalliance.org/news/page/2
#   Crawling (depth 2): https://www.pmdalliance.org/2025/05/28/recognition-roundup-june-cpdc
#   Crawling (depth 2): https://www.pmdalliance.org/2025/05/01/learner-rev-urinary-challenges
#   Crawling (depth 2): https://www.pmdalliance.org/2025/06/03/weary-warrior
#   Crawling (depth 2): https://www.pmdalliance.org/2025/06/03/movement-disorder-care-mt-nv-wy
#   Crawling (depth 2): https://www.pmdalliance.org/about/vision/ecosystem-the-companion-network
#   Crawling (depth 2): https://www.pmdalliance.org/about/vision/ecosystem-the-community-network
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/founders-story
#   Crawling (depth 2): https://www.pmdalliance.org/about/vision/ecosystem-the-family-network
#   Crawling (depth 2): https://www.pmdalliance.org/about/vision/ecosystem-the-medical-network
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/an-interview-with-pmd-alliance-founders-sarah-jones-and-judy-talley
#   Crawling (depth 2): https://www.pmdalliance.org/about/vision/ecosystem-the-therapy-network
#   Crawling (depth 2): https://www.pmdalliance.org/2024/12/04/all-in-24-recap
#   Crawling (depth 2): https://www.pmdalliance.org/all-in-summit/speakers
#   Crawling (depth 2): https://www.pmdalliance.org/resources/resources-national-regional-local-resources
#   Crawling (depth 2): https://www.pmdalliance.org/bldg-your-med-network
#   Crawling (depth 2): http://www.pmdalliance.org
#   Crawling (depth 2): https://www.pmdalliance.org/carefree-retreat
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-amantadine
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-xeomin
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-nuplazid
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-exelon
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-ongentys
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-cogentin
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-apokyn
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-nourianz
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-neupro
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-gocovri
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-inbrija
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-azilect
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-northera
#   Crawling (depth 2): https://www.pmdalliance.org/treatmentoptions/themoreyouknow/page/2
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-mirapex
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-rytary
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-sinemet
#   Crawling (depth 2): https://www.pmdalliance.org/portfolio/the-more-you-know-onapgo
# Crawling ParkinsonNet...
#   Crawling (depth 0): https://www.parkinsonnet.com/
#   Crawling (depth 1): https://www.parkinsonnet.com/about-parkinsonnet/around-the-globe
#   Crawling (depth 1): https://www.parkinsonnet.com/succes-stories/partner-of-person-with-pd
#   Crawling (depth 1): https://www.parkinsonnet.com/discipline/speech-and-language
#   Crawling (depth 1): https://www.parkinsonnet.com/discipline/physiotherapy
#   Crawling (depth 1): https://www.parkinsonnet.com/about-parkinsonnet
#   Crawling (depth 1): https://www.parkinsonnet.com/about-parkinsonnet/scientific-evidence
#   Crawling (depth 1): https://www.parkinsonnet.com/discipline/nutrition
#   Crawling (depth 1): https://www.parkinsonnet.com
#   Crawling (depth 1): https://www.parkinsonnet.com/contact
#   Crawling (depth 1): https://www.parkinsonnet.com/news/royal-honors-for-marten-munneke-and-bas-bloem
#   Crawling (depth 1): https://www.parkinsonnet.com/news/letter-of-intent-signed-in-osnabruck
#   Crawling (depth 1): https://www.parkinsonnet.com/succes-stories/christopher-c-distasio
#   Crawling (depth 1): https://www.parkinsonnet.com/news/world-parkinson-congress-in-barcelona-a-recap
#   Crawling (depth 1): https://www.parkinsonnet.com/about-parkinsonnet/our-team
#   Crawling (depth 1): https://www.parkinsonnet.com/about-parkinsonnet/services
#   Crawling (depth 1): https://www.parkinsonnet.com/news/lets-celebrate-parkinsonnet-20-years
#   Crawling (depth 1): https://www.parkinsonnet.com/news/implementing-parkinsonnet-in-5th-gear
#   Crawling (depth 1): https://www.parkinsonnet.com/discipline/for-people-with-parkinsons
#   Crawling (depth 1): https://www.parkinsonnet.com/discipline/occupational-therapy
#   Crawling (depth 1): https://www.parkinsonnet.com/guidelines
#   Crawling (depth 2): https://www.parkinsonnet.com/our-team
# HTTP 404 for https://www.parkinsonnet.com/our-team
#   Crawling (depth 2): https://www.parkinsonnet.com/news
#   Crawling (depth 3): https://www.parkinsonnet.com/news/page/2
#   Crawling (depth 3): https://www.parkinsonnet.com/news/parkinsonnet-care-providers-reduce-complications-in-parkinsons-disease
#   Crawling (depth 3): https://www.parkinsonnet.com/news/page/3
#   Crawling (depth 3): https://www.parkinsonnet.com/news/skills-web-2022-a-recap
#   Crawling (depth 3): https://www.parkinsonnet.com/news/parkinsontv-the-long-road-to-hope
#   Crawling (depth 3): https://www.parkinsonnet.com/news/staying-connected-online
#   Crawling (depth 3): https://www.parkinsonnet.com/news/5-years-of-parkinsonnet-luxembourg
# Results saved to parkinsons_full_crawl.json
# Results saved to parkinsons_crawl_summary.json
#
# === CRAWLING SUMMARY ===
# Total Organizations: 9
# Successful Crawls: 9
# Failed Crawls: 0
# Total Pages Scraped: 618
# Total Videos Found: 561
# Total Podcasts Found: 78
#
# === ORGANIZATION DETAILS ===
# Parkinson's Foundation: 99 pages, 46 videos, 48 podcasts (depth: 2)
# Michael J. Fox Foundation: 98 pages, 68 videos, 17 podcasts (depth: 1)
# American Parkinson Disease Association: 93 pages, 231 videos, 6 podcasts (depth: 2)
# Parkinson Canada: 100 pages, 29 videos, 0 podcasts (depth: 2)
# European Parkinson's Disease Association: 0 pages, 0 videos, 0 podcasts (depth: 0)
# Parkinson's UK: 100 pages, 58 videos, 6 podcasts (depth: 1)
# Davis Phinney Foundation: 0 pages, 0 videos, 0 podcasts (depth: 0)
# PMD Alliance: 99 pages, 119 videos, 1 podcasts (depth: 2)
# ParkinsonNet: 29 pages, 10 videos, 0 podcasts (depth: 3)

# %%
from google.colab import files

# Download the files to your local computer
files.download('parkinsons_full_crawl.json')
files.download('parkinsons_crawl_summary.json')
